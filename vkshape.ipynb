# %% [markdown]
# <a href="https://colab.research.google.com/github/khiromcmiwiw/23420023-tokenization/blob/main/vkshape.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IMPORT LIBRARY YANG DIBUTUHKAN
from skimage.io import imread
from skimage.transform import resize
from skimage.feature import hog
from skimage import exposure
import matplotlib.pyplot as plt

# MEMBACA GAMBAR
img = imread('CRF150.jpg')
plt.axis("off")
plt.imshow(img)
print(img.shape)
# Out:
# (383, 550, 3)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# MERUBAH UKURAN GAMBAR
resized_img = resize(img, (64*4, 128*4))
plt.axis("off")
plt.imshow(resized_img)
print(resized_img.shape)
# Out:
# (256, 512, 3)

# %%
fd, hog_image = hog(resized_img, orientations=9, pixels_per_cell=(8, 8),
                    cells_per_block=(2, 2), visualize=True, multichannel=True)
plt.axis("off")
plt.imshow(hog_image, cmap="gray")
# Out:
# <ipython-input-5-621932626964>:1: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   fd, hog_image = hog(resized_img, orientations=9, pixels_per_cell=(8, 8),
